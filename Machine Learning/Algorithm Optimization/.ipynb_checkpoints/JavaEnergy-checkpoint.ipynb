# %%
# Pandas for managing datasets
import pandas as pd

# Numpy and Random for math
import numpy as np

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

data = pd.read_csv('Data/Windows.csv')
energy_data = pd.read_csv('Data/EnergyOutput.csv')
data = clean_dataset(data)
#data = data.query('windowSize==63')
'''
print len(data['energyg1'])
print len(energy_data['gx'])
data['energyg1'] = energy_data['gx'].values
data['energyg2'] = energy_data['gy'].values
data['energyg3'] = energy_data['gz'].values
data['energya1'] = energy_data['ax'].values
data['energya2'] = energy_data['ay'].values
data['energya3'] = energy_data['az'].values

data.to_csv('Data/JavaEnergy.csv', sep=',', index=False)
'''
data.head()
# Out:
#        participantID  windowSize       mg1   stdevg1  energyg1       mg2  \
# 74767            8.0        63.0 -0.289394  2.114732     -37.0  0.218593
# 74768            8.0        63.0 -0.237010  1.994774      70.0  0.440163
# 74769            8.0        63.0  0.103630  1.740111      -8.0 -0.206414
# 74770            8.0        63.0 -0.141177  2.590848      13.0 -0.799157
# 74771            8.0        63.0  0.249612  2.191180      60.0 -0.282214
#
#         stdevg2  energyg2       mg3   stdevg3  ...        g2a1      g2a2  \
# 74767  2.568680     -78.0 -0.023335  2.763296  ...    0.529514  0.573157
# 74768  2.449596      16.0  0.086384  2.566416  ...    0.497843  0.546254
# 74769  2.799666     110.0  0.214534  2.345758  ...    0.600453  0.469909
# 74770  2.765088      93.0  0.180791  2.729532  ...    0.531197  0.551365
# 74771  2.735275     -64.0 -0.022772  2.747151  ...    0.469321  0.457445
#
#            g2a3      g3a1      g3a2      g3a3      a1a2      a1a3      a2a3  \
# 74767  0.531510  0.547877  0.392669  0.481131  0.465920  0.465920  0.447610
# 74768  0.426900  0.595283  0.361820  0.492332  0.325953  0.325953  0.499548
# 74769  0.554674  0.632614  0.470239  0.572246  0.479990  0.479990  0.434002
# 74770  0.560002  0.602003  0.371436  0.427489  0.533379  0.533379  0.602735
# 74771  0.576865  0.461591  0.405748  0.564600  0.667453  0.667453  0.377741
#
#        label
# 74767    5.0
# 74768    5.0
# 74769    5.0
# 74770    5.0
# 74771    5.0
#
# [5 rows x 36 columns]
